# %% [markdown]
# <a href="https://colab.research.google.com/github/2xjialjl/1027ai-/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hellow word')
# Out:
# hellow word

# %%
gvbhjklm

# %%
841562rtfygbhunji
